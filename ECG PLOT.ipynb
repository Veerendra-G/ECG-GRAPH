# %%
path = r'C:\Users\hp\Downloads\raw_ecg (2).csv'
import pandas as pd
df = pd.read_csv(path)
print(df)
import matplotlib.pyplot as plt
plt.title("ECG signal - 1000")
plt.plot(df.ecg[0:500])
plt.xlabel('Time (seconds)')
plt.show()
# Out:
#              id  ecg  ca_id          device_id  patient_id  clinic_id  \
# 0      20654775  532  cl_21  11:3E:E2:A6:DC:A1          24          1
# 1      20654776  532  cl_21  11:3E:E2:A6:DC:A1          24          1
# 2      20654777  532  cl_21  11:3E:E2:A6:DC:A1          24          1
# 3      20654778  532  cl_21  11:3E:E2:A6:DC:A1          24          1
# 4      20654779  532  cl_21  11:3E:E2:A6:DC:A1          24          1
# ...         ...  ...    ...                ...         ...        ...
# 24599  20679374  529  cl_21  11:3E:E2:A6:DC:A1          24          1
# 24600  20679375  530  cl_21  11:3E:E2:A6:DC:A1          24          1
# 24601  20679376  533  cl_21  11:3E:E2:A6:DC:A1          24          1
# 24602  20679377  535  cl_21  11:3E:E2:A6:DC:A1          24          1
# 24603  20679378  537  cl_21  11:3E:E2:A6:DC:A1          24          1
#
#                  timestamp
# 0      2024-07-17 11:48:08
# 1      2024-07-17 11:48:08
# 2      2024-07-17 11:48:08
# ...
